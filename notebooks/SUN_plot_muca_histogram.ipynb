# %%
# %load_ext autoreload
# %autoreload 2
from modules import read_and_write
from modules import wilson_action
from modules import utility
import pandas as pd
from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats('svg')
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
# Load the file as a CSV
file_path = '/home/haaaaron/HILA/applications/suN_gauge_twist/intermediate_weight.dat'
file_path = '/home/haaaaron/HILA/applications/suN_gauge_twist/30-30-48-6-10.8053-twist-1'
data = pd.read_csv(file_path, delimiter='\t', header=0)
print(data)
# Plot the histogram
plt.plot(data["OP_value"][:-1],data["Weight"][:-1])
plt.bar(data["OP_value"][:-1], data["Weight"][:-1], width=0.00002)
plt.xlabel('Bins')
plt.ylabel('Weights')
plt.title('Histogram')
plt.show()
# Out:
#     OP_bin_limit  OP_value    Weight
# 0       0.435785  0.435800  0.903332
# 1       0.435815  0.435831  2.539490
# 2       0.435846  0.435861  2.882262
# 3       0.435877  0.435892  3.067492
# 4       0.435907  0.435922  3.539383
# 5       0.435938  0.435953  3.311860
# 6       0.435968  0.435984  3.851310
# 7       0.435999  0.436014  4.023311
# 8       0.436030  0.436045  4.804840
# 9       0.436060  0.436076  4.933987
# 10      0.436091  0.436106  5.258734
# 11      0.436121  0.436137  5.491555
# 12      0.436152  0.436167  5.279240
# 13      0.436183  0.436198  6.005659
# 14      0.436213  0.436229  5.935198
# 15      0.436244  0.436259  6.441224
# 16      0.436275  0.436290  6.315314
# 17      0.436305  0.436320  6.506881
# 18      0.436336  0.436351  6.612409
# 19      0.436366  0.436382  6.729064
# 20      0.436397  0.436412  6.719899
# 21      0.436428  0.436443  6.928785
# 22      0.436458  0.436474  7.068714
# 23      0.436489  0.436504  7.115624
# ...
