# %%
# %load_ext autoreload
# %autoreload 2
from modules import read_and_write
from modules import polyakov
from modules import utility

# %%
plaquette_data_0= read_and_write.load_from_folder("./output_sun4/traj_120000_t2/output-joined/output_twist_0","polyakov:", "complex")

# %%
plaquette_data_1= read_and_write.load_from_folder("./output_sun4/traj_120000_t2/output-joined/output_twist_1","polyakov:", "complex")

# %%
plaquette_data_2= read_and_write.load_from_folder("./output_sun4/traj_120000_t2/output-joined/output_twist_2","polyakov:", "complex")

# %%
polyakov.create_figure_polar(utility.select_subset(plaquette_data_0,0,19),mean=True)
# Out:
# something

# %%
polyakov.create_figure_polar(plaquette_data_2,mean=True)
# Out:
# something
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 polyakov.create_figure_polar(plaquette_data_2,mean=False)
#
# File ~/SUN_twist_python_analysis/modules/polyakov.py:50, in create_figure_polar(datas, cols, mean, title)
#      48 #plt.xticks([float(x) for x in datas[0].head()[1:-1]])
#      49 fig.tight_layout(pad=0.4, w_pad=1, h_pad=1.0)
# ---> 50 plt.show()
#
# File ~/SUN_twist_python_analysis/env/lib/python3.10/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/SUN_twist_python_analysis/env/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
# ...

# %%
polyakov.create_figure_real_imag(utility.select_subset(plaquette_data_0,0,19),mean=True)

# %%
polyakov.create_figure_real_imag(utility.sort_plaquette_dict(plaquette_data_1),mean=True)

# %%
polyakov.create_figure_real_imag(utility.select_subset(plaquette_data_2,0,19),mean=True)
