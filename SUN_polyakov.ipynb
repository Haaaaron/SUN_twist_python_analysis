# %%
# %load_ext autoreload
# %autoreload 2
from modules import read_and_write
from modules import polyakov
from modules import utility
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plaquette_data_notwist = read_and_write.load_from_folder("./current_output/notwist","polyakov:", "complex")

# %%
plaquette_data_twist = read_and_write.load_from_folder("./current_output/twist","polyakov:", "complex")

# %%
polyakov.create_figure_polar(utility.select_subset(plaquette_data_twist,0,12),mean=True)

# %%
polyakov.create_figure_polar(utility.select_subset(plaquette_data_notwist,0,12),mean=True)

# %%
polyakov.create_figure_real(utility.select_subset(plaquette_data_notwist,0,12),mean=True)
