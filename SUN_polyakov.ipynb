# %%
# %load_ext autoreload
# %autoreload 2
from modules import read_and_write
from modules import polyakov
from modules import utility

# %%
plaquette_data_notwist = read_and_write.load_from_folder("./output_sun4/output_notwist","polyakov:", "complex")

# %%
plaquette_data_twist = read_and_write.load_from_folder("./output_sun4/output_twist","polyakov:", "complex")

# %%
polyakov.create_figure_polar(utility.select_subset(plaquette_data_twist,0,12),mean=False)
# Out:
# something

# %%
polyakov.create_figure_polar(utility.select_subset(plaquette_data_notwist,0,12),mean=True)
# Out:
# something

# %%
polyakov.create_figure_real_imag(utility.select_subset(plaquette_data_notwist,0,12),mean=True)

# %%
polyakov.create_figure_real_imag(utility.select_subset(plaquette_data_twist,0,12),mean=True)

# %%
errors = utility.compute_with_aa(utility.select_subset(plaquette_data_twist,0,2))
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 errors = utility.compute_with_aa(utility.select_subset(plaquette_data_twist,0,2))
#
# File ~/SUN_twist_python_analysis/modules/utility.py:28, in compute_with_aa(data)
#      26         empty_array.append(line.split())
#      27 error_data = np.array(empty_array)
# ---> 28 error_data = np.delete(error_data, 0,1)
#      29 error_data = pd.DataFrame(error_data,columns=["average","error","atocorrelation","autocorrelation", "ind.meas"])
#      30 error_dict[name] = error_data
#
# File ~/SUN_twist_python_analysis/env/lib/python3.10/site-packages/numpy/lib/function_base.py:5254, in delete(arr, obj, axis)
#    5252     axis = ndim - 1
#    5253 else:
# -> 5254     axis = normalize_axis_index(axis, ndim)
#    5256 slobj = [slice(None)]*ndim
#    5257 N = arr.shape[axis]
#
# ...
